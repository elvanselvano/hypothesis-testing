# %% [markdown]
# ## Cookie Cats: A/B Testing Case Study
#
# ![](https://i.ytimg.com/vi/LkvnfULq8yQ/maxresdefault.jpg)
#
# **Background**
#
# [Cookie Cats](https://www.facebook.com/cookiecatsgame) is a hugely popular mobile puzzle game developed by [Tactile Entertainment](http://tactile.dk). It's a classic "connect three" style puzzle game where the player must connect tiles of the same color in order to clear the board and win the level. It also features singing cats. We're not kidding!
#
# As players progress through the levels of the game, they will occasionally encounter gates that force them to wait a non-trivial amount of time or make an in-app purchase to progress. In addition to driving in-app purchases, these gates serve the important purpose of giving players an enforced break from playing the game, hopefully resulting in that the player's enjoyment of the game being increased and prolonged.
#
# But where should the gates be placed? Initially the first gate was placed at level 30, but what would happen if we moved the first gate in Cookie Cats from level 30 to level 40. In particular, we will look at the impact on player retention.
#
# *Reference: [Datacamp projects](https://www.datacamp.com/projects/184)*
#
# **Data Description**
#
# | Column         | Description                                                                                                                          | Values             |
# |----------------|--------------------------------------------------------------------------------------------------------------------------------------|--------------------|
# | userid         | a unique number that identifies each player                                                                                          | Unique Identifier  |
# | version        | whether the player was put in the control group ( gate_30  - a gate at level 30) or the test group ( gate_40  - a gate at level 40). | [gate_30, gate_40] |
# | sum_gamerounds | number of game rounds played during the first 14 days after installation                                                                | Numerical Values   |
# | retention_1    | whether the player come back and play 1 day after installing                                                                         | [TRUE, FALSE]      |
# | retention_7    | whether the player come back and play 7 days after installing                                                                        | [TRUE, FALSE]      |
#
# **Metric**
#
# A common metric in the video gaming industry for how fun and engaging a game is retention: The percentage of players that come back and play the game 1-day and 7-days after they have installed it. The higher retention is, the easier it is to retain players and build a large player base.
#
# **Acknowledgements**
#
# The data is taken from Kaggle Datasets: [Cookie Cats](https://www.kaggle.com/yufengsui/mobile-games-ab-testing). The data we have is from 90,189 players that installed the game while the AB-test was running. Note that when a player installed the game, the player was randomly assigned to either version `gate_30` or version `gate_40`.

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from scipy.stats import shapiro
import scipy.stats as stats

import memory_optimizer as mo
import imp

imp.reload(mo)
plt.style.use('fivethirtyeight')

# %% [markdown]
# ### Data Understanding

# %% [markdown]
# Before we do any analysis, we will first take a look at the data using `pandas-profiling`. This will give us a quick overview of the data and give us a quick idea of the distribution of the data. The result of `pandas-profiling` is a nice looking report in `.html`.
#
# From the report, we can conclude that:
#
# - `userid` has unique values.
# - `gate_30` and `gate_40` are the only two groups in `version` and the number of users that are in each group are not equal. SRM analysis will be performed.
# - `sum_gamerounds` has 3994 zeros meaning that 4.4% of the users did not play the game during the first 14 days after installataion. It is also highly skewed with one of the player having played for over 45,000 rounds.
# - Both `retention_1` and `retention_7` are highly correlated with `sum_gamerounds`.
# - There are no missing values or duplicated rows.

# %%
df = pd.read_csv('cookie_cats.csv', engine='pyarrow') # using apache arrow engine
df
# Out:
#         userid  version  sum_gamerounds  retention_1  retention_7
# 0          116  gate_30               3        False        False
# 1          337  gate_30              38         True        False
# 2          377  gate_40             165         True        False
# 3          483  gate_40               1        False        False
# 4          488  gate_40             179         True         True
# ...        ...      ...             ...          ...          ...
# 90184  9999441  gate_40              97         True        False
# 90185  9999479  gate_40              30        False        False
# 90186  9999710  gate_30              28         True        False
# 90187  9999768  gate_40              51         True        False
# 90188  9999861  gate_40              16        False        False
#
# [90189 rows x 5 columns]

# %% [markdown]
# We will also optimize the memory usage of the dataframe by downcasting the data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90189 entries, 0 to 90188
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   userid          90189 non-null  int64
#  1   version         90189 non-null  object
#  2   sum_gamerounds  90189 non-null  int64
#  3   retention_1     90189 non-null  bool
#  4   retention_7     90189 non-null  bool
# dtypes: bool(2), int64(2), object(1)
# memory usage: 2.2+ MB

# %%
df = mo.optimize(df)
# Out:
# Memory usage before optimization: 7.053 MB
# Memory usage after optimization: 0.946 MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90189 entries, 0 to 90188
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   userid          90189 non-null  int32
#  1   version         90189 non-null  category
#  2   sum_gamerounds  90189 non-null  int32
#  3   retention_1     90189 non-null  bool
#  4   retention_7     90189 non-null  bool
# dtypes: bool(2), category(1), int32(2)
# memory usage: 969.1 KB

# %%
def check_uniqueness(df, id):
    return df[id].nunique() == df.shape[0]

# %%
check_uniqueness(df, 'userid')
# Out:
# True

# %%
msno.matrix(df, figsize=(10,4))
plt.show()

# %% [markdown]
# Lastly, we will also perform sample ratio mismatch (SRM) analysis to see if there is any difference in the sample ratio of the two groups. This is one of the way to track the data integrity in the experiment. The way to measure this is by doing chi-squared test of independence. This test tells us that, given two samples, the probability that the samples are independent. The formula is as follows:
#
# ![](https://www.statisticshowto.com/wp-content/uploads/2013/09/chi-square-formula.jpg)
#
# where:
#
# - `Xc^2` is the Pearson's chi-squared test,
# - `Oi` is the observed frequency counts in each category,
# - `Ei` is the expected frequency counts in each category.
#
# Note that the degree of freedom will be used to analyze the critical value. Degree of freedom can be calculated as `(R-1) * (C-1)` where R is the number of rows and C is the number of columns from the contingency table.
#
# Reference:
#
# - https://www.statstest.com/cramers-v-2
# - https://www.ibm.com/docs/en/cognos-analytics/11.1.0?topic=terms-cramrs-v
# - https://www.educba.com/degrees-of-freedom-formula/

# %%
df.groupby('version').count()
# Out:
#          userid  sum_gamerounds  retention_1  retention_7
# version
# gate_30   44700           44700        44700        44700
# gate_40   45489           45489        45489        45489

# %%
def sample_ratio_mismatch(df, id, group, val1, val2):
   if check_uniqueness(df, id):
        total_traffic = df[id].nunique()
        users_in_control = df[df[group] == val1].shape[0]
        users_in_treatment = df[df[group] == val2].shape[0]
        observed = [users_in_control, users_in_treatment]
        expected = [total_traffic/2, total_traffic/2]
        
        chi_stats, p_value = stats.chisquare(observed, expected)
        print('Chi-squared test statistic: {}'.format(chi_stats))
        print('P-value: {}'.format(p_value))
        
        if p_value < 0.01:
           print('SRM may be present.')
        else:
           print('Probably no SRM.')

# %% [markdown]
# Normally, one would look for a p-value of 0.05 or less to determine independence (and, in our case, proof of SRM). But, it has been criticized for not being strict enough, therefore, we will be using a significance level of 0.01.
#
# Resource:
# - https://towardsdatascience.com/the-essential-guide-to-sample-ratio-mismatch-for-your-a-b-tests-96a4db81d7a4
# - https://medium.com/engineers-optimizely/a-better-way-to-test-for-sample-ratio-mismatches-srms-and-validate-experiment-implementations-6da7c0d64552

# %%
sample_ratio_mismatch(df, 'userid', 'version', 'gate_30', 'gate_40')
# Out:
# Chi-squared test statistic: 6.9024049496058275
# P-value: 0.008607987810836262
# SRM may be present.

# %% [markdown]
# From the result above, we can conclude that SRM may be present in the experiment. Therefore, it should be taken with consideration when analyzing the results below.

# %% [markdown]
# ### Exploratory Data Analysis
#
# In this part, we will analyze the correlation between the version. and `sum_gamerounds`. Then, we will proceed with hypothesis testing on retention and version.

# %% [markdown]
# ![](https://assets.datacamp.com/production/project_184/img/cc_gates.png)

# %%
def two_version_comparison(df, version, treatment_val, control_val, metric, skewed=False):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 5))
    df[(df[version] == control_val)].hist(metric, ax=axes[0])
    df[(df[version] == treatment_val)].hist(metric, ax=axes[1])
    sns.boxplot(x=version, y=metric, data=df, ax=axes[2])
    
    axes[0].set_title('Distribution of {}'.format(control_val))
    axes[1].set_title('Distribution of {}'.format(treatment_val))
    axes[2].set_title('Distribution of Two Groups')

# %% [markdown]
# From the result below, we can see that the mean and median of the two groups are very close although the standard deviation is quite different.

# %%
df.groupby('version')['sum_gamerounds'].agg(['count', 'mean', 'median', 'std', 'min', 'max'])
# Out:
#          count       mean  median         std  min    max
# version
# gate_30  44700  52.456264    17.0  256.716423    0  49854
# gate_40  45489  51.298776    16.0  103.294416    0   2640

# %%
two_version_comparison(df, 'version', 'gate_40', 'gate_30', 'sum_gamerounds')

# %%
plt.figure(figsize=(20, 6))
sns.histplot(x='sum_gamerounds', data=df, hue='version', bins=100)
plt.show()

# %% [markdown]
# Now, we will drop the row where the `sum_gamerounds` is 49854 because we conclude that it is nearly impossible for a player to play the game that much and if it is in fact possible, it is only one row and won't affect the result.

# %%
df[df['sum_gamerounds'] > df['sum_gamerounds'].quantile(0.9999)]
# Out:
#         userid  version  sum_gamerounds  retention_1  retention_7
# 6536    725080  gate_40            2015         True         True
# 7912    871500  gate_30            2961         True         True
# 29417  3271615  gate_40            2640         True        False
# 36933  4090246  gate_40            2124         True         True
# 43671  4832608  gate_30            2438         True         True
# 46344  5133952  gate_30            2251         True         True
# 48188  5346171  gate_40            2294         True         True
# 57702  6390605  gate_30           49854        False         True
# 87007  9640085  gate_30            2156         True         True
# 88328  9791599  gate_40            2063         True         True

# %%
df = df[df['sum_gamerounds'] < 3000].copy()

# %% [markdown]
# Now, we will try to compare the versions again.

# %%
two_version_comparison(df, 'version', 'gate_40', 'gate_30', 'sum_gamerounds')

# %%
def plot_skewed(df, version, control_val, treatment_val, metric):
    df[df[version] == control_val].reset_index().set_index('index')[metric].plot(legend=True, label='Gate 30 (Control)', figsize = (20,5))
    df[df[version] == treatment_val].reset_index().set_index('index')[metric].plot(legend=True, label='Gate 40 (Treatment)', alpha=0.65)

# %% [markdown]
# From the plot below, we can see there are no significant differences between the two versions in `sum_gamerounds`. We will validate this assumption using hypothesis testing.

# %%
plt.title('Distribution of {}'.format('sum_gamerounds'))
plot_skewed(df, 'version', 'gate_30', 'gate_40', 'sum_gamerounds')

# %% [markdown]
# But before that, let's take a look at the distribution of the data. We can see that the number of users decreases as the levels progress indicating which should be analyzed further.

# %%
fig, axes = plt.subplots(2, 1, figsize = (20,15))
df.groupby('sum_gamerounds').userid.count().plot(ax = axes[0])
df.groupby('sum_gamerounds').userid.count()[:100].plot(ax = axes[1])
axes[0].set_title('Number of Users by Game Rounds')
axes[1].set_title('How many users play the first 100 game rounds?')
plt.tight_layout(pad=5)
plt.show()

# %% [markdown]
# We can also check how many users are currently stuck at gate 30 and gate 40.

# %%
df.groupby('sum_gamerounds').userid.count().loc[[30, 40]].plot(kind='bar')
plt.title('Number of Users by Game Rounds (30 and 40)')
plt.show()

# %% [markdown]
# ### A/B Testing
#
# In doing A/B testing, we will first perform normality tests. If the data is normally distributed, we can use parametric tests. On the contrary, if data are not normally distributed, nonparametric tests will be use.

# %% [markdown]
# - **D'Agostino-Pearson test**
#
# > checks if the shape of the distribution is similar to the shape of the normal distribution. It uses a combination of the skewness test and the kurtosis test. Skewness test tests the null assumption that the data distribution is symmetric. Kurtosis test tests the null assumption that the kurtosis equals zero (kurtosis of the normal distribution).
#
#
# - **Shapiro-Wilk test**
#
# > is a way to tell if a random sample comes from a normal distribution. The test has limitations, most importantly that the test has a bias by sample size.
#
#
# -  **Levene’s test**
#
# > is an equal variance test. It can be used to check if our data sets fulfill the homogeneity of variance assumption before we perform the t-test or Analysis of Variance (ANOVA). The null hypothesis formed in the Levene’s test is that the groups we are comparing have equal variance. Note that variance is obtained by the sum of squared distances between a data point and the mean for each data point divided by the number of data points.
#
#
# -  **T-test**
#
# > is a popular and useful tool for hypothesis testing in statistics which can be used to determine if there is a significant difference in the means of the two groups. Note that there are different kinds of t-tests: one-sample t-test, two samples t-test, and paired samples t-test.
#
#
# -  **Mann-Whitney U test**
#
# > is the nonparametric equivalent of the two sample t-test. While the t-test makes an assumption about the distribution of a population (i.e. that the sample came from a t-distributed population), the Mann Whitney U Test makes no such assumption.
#
# Reference:
# - https://www.kaggle.com/hamelg/python-for-data-24-hypothesis-testing

# %%
def ab_test(df, group, target):
    # Split A/B
    groupA = df[df[group] == 'A'][target]
    groupB = df[df[group] == 'B'][target]

    # Assumption: Normality of the data
    # H0: The distribution is normal (False)
    # H1: The distribution is not normal (True)
    if(groupA.shape[0] > 5000 and groupB.shape[0] > 5000):
        print("Performing D'Agostino's K2 test")
        statistics, pvalueA = stats.normaltest(groupA)
        statistics, pvalueB = stats.normaltest(groupB)
        ntA = pvalueA < 0.05 # reject H0
        ntB = pvalueB < 0.05 # reject H0
    else:   
        ntA = shapiro(groupA)[1] < 0.05
        ntB = shapiro(groupB)[1] < 0.05 
    
    # If the data has normal distribution
    if ntA == False and ntB == False: 
        # Parametric test
        # Assumption: Homogeneity of variance
        # H0: Homogeneity of variance (False)
        # H1: Heterogeneity of variance (True)
        levene_result = stats.levene(groupA, groupB)[1] < 0.05
        
        # If the data has homogeneity of variance
        if levene_result == False:
            ttest = stats.ttest_ind(groupA, groupB, equal_var=True)[1]
            # H0: The two groups are not significantly different (False)
            # H1: The two groups are significantly different (True)
            
        else:
            ttest = stats.ttest_ind(groupA, groupB, equal_var=False)[1]
            # H0: The two groups are not significantly different (False)
            # H1: The two groups are significantly different (True)
            
    else:
        # Non-parametric test
        ttest = stats.mannwhitneyu(groupA, groupB)[1]
        # H0: The two groups are not significantly different (False)
        # H1: The two groups are significantly different (True)      
        
    # Hypothesis
    test_type = 'parametric' if ntA == False and ntB == False else 'non-parametric'
    result = 'Reject H0' if ttest < 0.05 else 'Fail to reject H0'
    
    print('H0: The two groups are not significantly different')
    print('H1: The two groups are significantly different')  
    print('P-value: {}'.format(ttest))
    print('Test type: {}'.format(test_type))
    print('Test result: {}'.format(result))

# %%
df['version'] = np.where(df['version'] == 'gate_30', 'A', 'B')
df['version'].value_counts()
# Out:
# B    45489
# A    44699
# Name: version, dtype: int64

# %% [markdown]
# By using hypothesis testing, we get a P-value of 0.0508. This means given the null hypothesis (`H0`) that the two groups have the same mean and the alternate hypothesis (`H1`) that the two groups have different means, there is 0.0508% chance that we mistakenly reject the null hypothesis. Also, because the p-value is higher than the significance level of 0.05, we fail to reject the null hypothesis.

# %%
ab_test(df=df, group='version', target='sum_gamerounds')
# Out:
# Performing D'Agostino's K2 test
# H0: The two groups are not significantly different
# H1: The two groups are significantly different
# P-value: 0.05089155279145376
# Test type: non-parametric
# Test result: Fail to reject H0

# %% [markdown]
# From the result above, we can conclude that version doesn't have any significant difference in `sum_gamerounds`. Now, we can proceed to analyze the retention which is our main metric. For this, we will be using bootstrap resampling and permutation test.

# %% [markdown]
# ### Bootstrap

# %% [markdown]
# The following is how bootstrap works:
# 1. First, decide on the number `k` of bootstraps you want to use. A reasonable number should be at least a hundred, depending on the final use of the bootstraps.
# 2. For every bootstrap to be computed, recreate a data set from the initial one with random sampling with replacement, this new data set having the same number of examples as the reference data set.
# 3. Compute the metric of interest on this new data set.
# 4. Use the `k` values of the metric either to conclude on the statistical significance of the test.
#
# Reference:
# - https://medium.com/criteo-engineering/why-your-ab-test-needs-confidence-intervals-bec9fe18db41

# %%
# Calculating 1-day and 7-days retention for each A/B group
df.groupby('version').agg({'userid':'count', 
                           'retention_1':'mean',
                           'retention_7': 'mean',
                           'sum_gamerounds':'sum'})
# Out:
#          userid  retention_1  retention_7  sum_gamerounds
# version
# A         44699     0.448198     0.190183         2294941
# B         45489     0.442283     0.182000         2333530

# %% [markdown]
# For this test, we will be using 10000 bootstraps.

# %%
def bootstrap_testing(df, group, metric, rounds=10000):
    bootstrap_result = []
    
    for _ in range(rounds):
        bootstrap_mean = df.sample(frac=1, replace=True).groupby(group)[metric].mean()
        bootstrap_result.append(bootstrap_mean)
        
    bootstrap_df = pd.DataFrame(bootstrap_result)
    
    # Plot the results
    fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(20,14))
    axes[0].set_title('Distribution of Bootstrap Samples')
    sns.kdeplot(data=bootstrap_df, shade=True, ax=axes[0])
    axes[0].axvline(bootstrap_df['A'].mean(), linestyle='--')
    axes[0].axvline(bootstrap_df['B'].mean(), color='red', linestyle='--')
    axes[0].set_xlabel('Probability')
    
    # Find % difference between the two AB-groups
    bootstrap_df['difference'] = (bootstrap_df['A'] - bootstrap_df['B']) / bootstrap_df['B'] * 100
    axes[1].set_title('% Difference between the two AB-groups')
    sns.kdeplot(data=bootstrap_df['difference'], ax=axes[1])
    axes[1].set_xlabel('% Difference')
    plt.tight_layout(pad=5);
    
    return bootstrap_df

# %% [markdown]
# From the results below, we can see that there is indeed a difference between the two versions in `retention_1` although it is very small. Also, note that as predicted by the central limit theorem, the distributions are roughly normal.

# %%
bootstrap_df = bootstrap_testing(df, 'version', 'retention_1')
print('Probability that 1-day retention is greater when the gate is at level 30:', (bootstrap_df['difference'] > 0).mean())

# Find 95% confidence intervals in the difference between the two AB-groups
lower_limit = np.percentile(bootstrap_df['difference'], 2.5)
upper_limit = np.percentile(bootstrap_df['difference'], 97.5)

print('95% confidence interval: [{}, {}]'.format(lower_limit, upper_limit))
# Out:
# Probability that 1-day retention is greater when the gate is at level 30: 0.9618
# 95% confidence interval: [-0.11931256657802013, 2.820512931118463]

# %% [markdown]
# For 7-day retention, we can see that the difference is more noticeable compared to 1-day retention. We will validate both of these assumptions using permutation testing later on.

# %%
bootstrap_df = bootstrap_testing(df, 'version', 'retention_7')
print('Probability that 7-day retention is greater when the gate is at level 30:', (bootstrap_df['difference'] > 0).mean())

# Find 95% confidence intervals in the difference between the two AB-groups
lower_limit = np.percentile(bootstrap_df['difference'], 2.5)
upper_limit = np.percentile(bootstrap_df['difference'], 97.5)

print('95% confidence interval: [{}, {}]'.format(lower_limit, upper_limit))
# Out:
# Probability that 7-day retention is greater when the gate is at level 30: 0.999
# 95% confidence interval: [1.6396002140440313, 7.395613221160742]

# %% [markdown]
# Lastly, we will also compare the two versions in `sum_gamerounds` just to support our hypothesis testing result above that the number of rounds are not significantly different between versions.

# %%
bootstrap_df = bootstrap_testing(df, 'version', 'sum_gamerounds')
print('Probability that rounds played is greater when the gate is at level 30:', (bootstrap_df['difference'] > 0).mean())

# Find 95% confidence intervals in the difference between the two AB-groups
lower_limit = np.percentile(bootstrap_df['difference'], 2.5)
upper_limit = np.percentile(bootstrap_df['difference'], 97.5)

print('95% confidence interval: [{}, {}]'.format(lower_limit, upper_limit))
# Out:
# Probability that rounds played is greater when the gate is at level 30: 0.5239
# 95% confidence interval: [-2.5390734940762547, 2.773482903572201]

# %% [markdown]
# ### Permutation Test
#
# Permutation testing starts off with `H0` that there is no difference between the groups. If `H0` is true, we should be able to randomly shuffle all the observed values between the groups without influencing their overall statistics.
#
# To check whether `H0` can be rejected: data is randomly shuffled `N` times and the difference between the randomly created groups is recorded each time. At the end, the actual difference can be compared to see how surprising the result would be under the null hypothesis.
#
# Note that we use permutation test because it doesn't require any assumptions about the distribution of the data.
#
# Reference:
# - https://towardsdatascience.com/the-power-of-permutation-testing-c2ac66f2d166
# - https://towardsdatascience.com/how-to-assess-statistical-significance-in-your-data-with-permutation-tests-8bb925b2113d

# %%
def permutation(df, group, metric):
    N = df.value_counts(group)[0]
    randomly_shuffled = np.random.permutation(df[metric].values)
    r1 = randomly_shuffled[:N].mean()
    r2 = randomly_shuffled[N:].mean()
    
    return r2-r1

def permutation_test(df, group, metric, num_simulations):
    simulated_results = []
    
    for _ in range(num_simulations):
        simulated_results.append(permutation(df, group, metric))
    
    return np.array(simulated_results)

# %% [markdown]
# The process will be repeated again and again to build a robust sample of simulations given that it would generally be impractical, even for a powerful computer, to explore every possible permutation of the results. This approach of taking a fixed number of samples rather than all possible permutations is known as the Monte Carlo method.

# %%
observed_difference = df.groupby('version')['retention_1'].mean()[0] - df.groupby('version')['retention_1'].mean()[1]
significance_level = 0.05
num_simulations = 10000
simulated_results = permutation_test(df, 'version', 'retention_1', num_simulations)
simulations_as_or_more_extreme = sum(simulated_results >= observed_difference)
p_value = simulations_as_or_more_extreme / num_simulations
significant_or_not = p_value < significance_level

print('Observed difference:', observed_difference)
print('Significance level:', significance_level)
print('Number of simulations:', num_simulations)
print('Number of simulations with simulated difference as or more extreme:', simulations_as_or_more_extreme)
print('The probabitlity of obtaining of a value of the test statistic that is at least as extreme as what we observed in the empirical data, under the assumption that the null hypothesis is true, is around', p_value)
print('Significant:', significant_or_not)
# Out:
# Observed difference: 0.005915196587034155
# Significance level: 0.05
# Number of simulations: 10000
# Number of simulations with simulated difference as or more extreme: 374
# The probabitlity of obtaining of a value of the test statistic that is at least as extreme as what we observed in the empirical data, under the assumption that the null hypothesis is true, is around 0.0374
# Significant: True

# %% [markdown]
# The final step is to determine whether we can reject the null hypothesis after comparing what we observed to the thousands of simulations run with random permutations of the data. With all of those random simulations performed, we can also visualize how unusual our observed result would be under the null hypothesis.

# %%
plt.figure(figsize=(18, 8))
density_plot = sns.kdeplot(simulated_results, shade=True)
density_plot.set(
    xlabel='Absolute Difference',
    ylabel='Proportion of Simulations',
    title='How Surprising Is Our Observed Result?'
)

# Add a line to show the actual difference observed in the data
density_plot.axvline(
    x=observed_difference, 
    color='red', 
    linestyle='--'
)

plt.legend(
    labels=['Simulated', 'Observed Difference'], 
    loc='upper right'
)
plt.show()

# %%
observed_difference = df.groupby('version')['retention_7'].mean()[0] - df.groupby('version')['retention_7'].mean()[1]
significance_level = 0.05
num_simulations = 10000
simulated_results = permutation_test(df, 'version', 'retention_7', num_simulations)
simulations_as_or_more_extreme = sum(simulated_results >= observed_difference)
p_value = simulations_as_or_more_extreme / num_simulations
significant_or_not = p_value < significance_level

print('Observed difference:', observed_difference)
print('Significance level:', significance_level)
print('Number of simulations:', num_simulations)
print('Number of simulations with simulated difference as or more extreme:', simulations_as_or_more_extreme)
print('The probabitlity of obtaining of a value of the test statistic that is at least as extreme as what we observed in the empirical data, under the assumption that the null hypothesis is true, is around', p_value)
print('Significant:', significant_or_not)
# Out:
# Observed difference: 0.00818318160884296
# Significance level: 0.05
# Number of simulations: 10000
# Number of simulations with simulated difference as or more extreme: 7
# The probabitlity of obtaining of a value of the test statistic that is at least as extreme as what we observed in the empirical data, under the assumption that the null hypothesis is true, is around 0.0007
# Significant: True

# %%
plt.figure(figsize=(18, 8))
density_plot = sns.kdeplot(simulated_results, shade=True)
density_plot.set(
    xlabel='Absolute Difference',
    ylabel='Proportion of Simulations',
    title='How Surprising Is Our Observed Result?'
)

# Add a line to show the actual difference observed in the data
density_plot.axvline(
    x=observed_difference, 
    color='red', 
    linestyle='--'
)

plt.legend(
    labels=['Simulated', 'Observed Difference'], 
    loc='upper right'
)
plt.show()

# %% [markdown]
# Based on the graphs above, especially in the 7-days retention, the observed difference is much higher than the 10000 differences created by random resampling. We can also see that from the p-value, both are statistically significant although for the `1-day retention`, the effect is not as strong as the `7-day retention`.
#
# Therefore, we can say that the difference between the means of these two versions is hardly explained by chance. Also, note that the observed difference is positive meaning that version `gate_30` is better than `gate_40` because it has higher retention in both `1-day retention` and `7-day retention`.
